# %% [markdown]
# ### Install necessary libraries

# %%
# !pip install pydub pyannote.audio openai-whisper
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: pyannote.audio in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.10/dist-packages (20240930)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (0.8.0)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (0.24.7)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (2.4.0)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (5.0.0)
# Requirement already satisfied: pyannote.database>=5.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (5.1.0)
# Requirement already satisfied: pyannote.metrics>=3.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (3.2.1)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (3.0.1)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (2.6.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (13.9.3)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (3.0.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (0.12.1)
# Requirement already satisfied: speechbrain>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (1.0.2)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (2.6.2.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (2.5.0+cu121)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (0.11.1)
# Requirement already satisfied: torchaudio>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (2.5.0+cu121)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio) (1.5.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.5.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.8.0)
# Requirement already satisfied: triton>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (3.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2.32.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio) (0.11.8)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio) (2.4.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (4.9.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=5.0.0->pyannote.audio) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=5.0.0->pyannote.audio) (1.13.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=5.0.1->pyannote.audio) (2.2.2)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=5.0.1->pyannote.audio) (0.12.5)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (1.5.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (3.7.1)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio) (1.13.1)
# Requirement already satisfied: optuna>=3.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.pipeline>=3.0.1->pyannote.audio) (4.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->pyannote.audio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->pyannote.audio) (2.18.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->pyannote.audio) (1.17.1)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.10/dist-packages (from speechbrain>=1.0.0->pyannote.audio) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain>=1.0.0->pyannote.audio) (1.4.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain>=1.0.0->pyannote.audio) (0.2.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX>=2.6->pyannote.audio) (3.20.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->pyannote.audio) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->pyannote.audio) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.1->pyannote.metrics>=3.2->pyannote.audio) (1.3.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (0.10.2.post1)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (1.2.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2024.9.11)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.10.10)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (3.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0.1->pyannote.audio) (75.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (2.8.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (1.13.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (2.0.36)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio) (3.5.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.10/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio) (1.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio) (1.5.4)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /usr/local/lib/python3.10/dist-packages (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio) (0.18.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->pyannote.audio) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (4.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (1.3.6)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio) (4.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio) (0.2.12)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (3.1.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (0.2.0)

# %% [markdown]
# ### Import the libraries

# %%
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pyannote.audio import Pipeline
import whisper
import tempfile
import os
import json
from tqdm import tqdm
import torch

# %% [markdown]
# ### Initialize Diarization and ASR Models

# %%
pipeline = Pipeline.from_pretrained('pyannote/speaker-diarization-3.1',
                                    use_auth_token='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')
asr_model = whisper.load_model("base")
# Out:
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 65.3MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)

# %% [markdown]
# ##### Use GPU

# %%
pipeline.to(torch.device("cuda"))

# %% [markdown]
# ### Preprocess the audio file

# %% [markdown]
# Preprocess the audio by converting it to mono channel, resampling to the target rate, and splitting on silence for long audio files.
#
# **Sample Rate = 16kHz**
#
# **Chunk Size = 5 mins or 300000 milliseconds**

# %%
def preprocess_audio(file_path, target_sample_rate=16000, chunk_duration=300000):
    audio = AudioSegment.from_file(file_path)
    print('File loaded.')

    audio = audio.set_channels(1).set_frame_rate(target_sample_rate)
    print('Preprocessing done.')

    print('Breaking the file into chunks.')
    # Split on silence
    chunks = [audio[i:i + chunk_duration] for i in range(0, len(audio), chunk_duration)]
    print('Chunking done.')

    return chunks

# %% [markdown]
# ### Diarization and Transcription

# %% [markdown]
# Each audio file will be made of chunks and each chunk will be diarized and transcribed individually.

# %%
def diarize_transcribe_chunk(chunk, chunk_index, base_timestamp=0):
    with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as temp_file:
        chunk.export(temp_file.name, format="wav")
        temp_file_path = temp_file.name

    # Diarization
    diarization = pipeline({"audio": temp_file_path})
    diarization_segments = [
        {"speaker": turn[2], "start": turn[0].start, "end": turn[0].end}
        for turn in diarization.itertracks(yield_label=True)
    ]

    # Transcription
    transcription_data = []
    for segment in diarization_segments:
        start, end = segment["start"], segment["end"]

        # converting seconds to milliseconds
        segment_audio = chunk[start * 1000: end * 1000]

        with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as temp_segment_file:
            segment_audio.export(temp_segment_file.name, format="wav")

            segment_text = asr_model.transcribe(temp_segment_file.name, language='en')['text']

            transcription_data.append({
                "speaker": segment["speaker"],
                "start_time": start + base_timestamp,
                "end_time": end + base_timestamp,
                "text": segment_text
            })

        # clean up the temporary files
        os.remove(temp_segment_file.name)

    os.remove(temp_file_path)

    return transcription_data

# %% [markdown]
# ### Process the entire file

# %% [markdown]
# Process the entire audio file:
#
# 1. Chunking
# 2. Preprocessing
# 3. Diarizing
# 4. Transcribing each chunk
# 5. Combining the results into JSON format

# %%
def process_audio(file_path):
    # Chunking and preprocessing
    chunks = preprocess_audio(file_path)

    final_transcription = []

    print('Proceeding with Speaker Diarization and Transcription...')

    # Diarization and Transcription
    for index, chunk in tqdm(enumerate(chunks)):
        # base timestamp of each chunk
        base_timestamp = index * chunk.duration_seconds
        chunk_transcription = diarize_transcribe_chunk(chunk, index, base_timestamp)
        final_transcription.extend(chunk_transcription)

    # JSON output
    transcription = {
        "transcription": [
            {
                "start_time": entry["start_time"],
                "end_time": entry["end_time"],
                "speaker": entry["speaker"],
                "text": entry["text"]
            }
            for entry in tqdm(final_transcription)
        ]
    }

    return transcription

# %% [markdown]
# ## Get the results

# %%
file_path = '/content/drive/MyDrive/Proj/IN1001.Mix-Headset.wav'
transcription_output = process_audio(file_path)

# Print JSON output
print(json.dumps(transcription_output, indent=2))
# Out:
# File loaded.
# Preprocessing done.
# Breaking the file into chunks.
# Chunking done.
# Proceeding with Speaker Diarization and Transcription...
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/pyannote/audio/utils/reproducibility.py:74: ReproducibilityWarning: TensorFloat-32 (TF32) has been disabled as it might lead to reproducibility issues and lower accuracy.
# It can be re-enabled by calling
#    >>> import torch
#    >>> torch.backends.cuda.matmul.allow_tf32 = True
#    >>> torch.backends.cudnn.allow_tf32 = True
# See https://github.com/pyannote/pyannote-audio/issues/1370 for more details.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1823.)
#   std = sequences.std(dim=-1, correction=1)
# 12it [07:54, 39.52s/it]
# 100%|██████████| 866/866 [00:00<00:00, 758143.87it/s]
# {
#   "transcription": [
#     {
#       "start_time": 4.4353437499999995,
#       "end_time": 4.53659375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 6.59534375,
#       "end_time": 7.000343750000001,
#       "speaker": "SPEAKER_00",
#       "text": " What?"
#     },
#     {
#       "start_time": 7.21971875,
#       "end_time": 7.27034375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 7.27034375,
#       "end_time": 8.957843750000002,
#       "speaker": "SPEAKER_00",
#       "text": " I think you don't. I think you're right."
#     },
#     {
#       "start_time": 8.957843750000002,
#       "end_time": 8.99159375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 13.88534375,
#       "end_time": 14.087843750000001,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 14.222843750000003,
#       "end_time": 14.239718750000002,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 14.30721875,
#       "end_time": 14.324093750000003,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 14.340968750000002,
#       "end_time": 18.559718750000002,
#       "speaker": "SPEAKER_01",
#       "text": " I am the\u674e\u5a51\u56fd team who acts as the best in my life. And I am standing up on the table crying. Opposite fans!"
#     },
#     {
#       "start_time": 16.73721875,
#       "end_time": 16.90596875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 16.973468750000002,
#       "end_time": 16.99034375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 18.96471875,
#       "end_time": 22.00221875,
#       "speaker": "SPEAKER_01",
#       "text": " Which are to be seen on the interview."
#     },
#     {
#       "start_time": 23.672843750000002,
#       "end_time": 24.398468750000003,
#       "speaker": "SPEAKER_00",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 24.97221875,
#       "end_time": 24.989093750000002,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 25.96784375,
#       "end_time": 28.02659375,
#       "speaker": "SPEAKER_00",
#       "text": " I'm not sure if I can do that."
#     },
#     {
#       "start_time": 29.86596875,
#       "end_time": 29.882843750000003,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 31.97534375,
#       "end_time": 32.025968750000004,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 32.09346875,
#       "end_time": 32.39721875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 33.05534375,
#       "end_time": 33.40971875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 41.59409375,
#       "end_time": 46.31909375,
#       "speaker": "SPEAKER_01",
#       "text": " You don't put your headset microphone."
#     },
#     {
#       "start_time": 43.12971875,
#       "end_time": 45.711593750000006,
#       "speaker": "SPEAKER_00",
#       "text": " It's at my girlfriend."
#     },
#     {
#       "start_time": 48.158468750000004,
#       "end_time": 49.59284375,
#       "speaker": "SPEAKER_00",
#       "text": " So, it's in the country."
#     },
#     {
#       "start_time": 50.588468750000004,
#       "end_time": 51.34784375,
#       "speaker": "SPEAKER_00",
#       "text": " Everything."
#     },
#     {
#       "start_time": 77.99346875,
#       "end_time": 81.09846875000001,
#       "speaker": "SPEAKER_00",
#       "text": " So we are here to just make the point."
#     },
#     {
#       "start_time": 81.31784375000001,
#       "end_time": 120.02909375,
#       "speaker": "SPEAKER_00",
#       "text": " Well, make the point. Make the status about the shot detection. Okay. So you have applied the shot detector to some of the synities video, this one. And so we can basically maybe just comment on this, maybe quickly remind what the shot detector is, how the shot detector is working, basically. We might be able anyway to give you some reference, I mean your report, it should be described there. Yeah, I have actually, yeah, we can see the report."
#     },
#     {
#       "start_time": 85.23284375,
#       "end_time": 85.36784375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 88.84409375,
#       "end_time": 89.33346875000001,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 94.95284375,
#       "end_time": 95.32409375,
#       "speaker": "SPEAKER_01",
#       "text": " We're here."
#     },
#     {
#       "start_time": 101.12909375000001,
#       "end_time": 101.24721875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 106.74846875,
#       "end_time": 107.03534375000001,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 115.15221875,
#       "end_time": 116.97471875000001,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, it should be described here."
#     },
#     {
#       "start_time": 117.09284375000001,
#       "end_time": 132.53346875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, I have actually, yeah, we can see the report here and the demo. And the goal of this meeting is to present the video shot detected to Olivier."
#     },
#     {
#       "start_time": 130.71096875,
#       "end_time": 132.01034375,
#       "speaker": "SPEAKER_00",
#       "text": " Olivier. Olivier, OK."
#     },
#     {
#       "start_time": 135.03096875,
#       "end_time": 162.03096875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay, so yeah, it was my project during my internship at Ethiopia and there's a suppression of remark and as you saw in the email I sent... Okay, I didn't send... this video is the new one, I just processed from your images."
#     },
#     {
#       "start_time": 162.55409375000002,
#       "end_time": 165.96284375000002,
#       "speaker": "SPEAKER_00",
#       "text": " Ok, yeah, but let's start by the..."
#     },
#     {
#       "start_time": 162.85784375,
#       "end_time": 169.91159375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, but let's start by the video from Friday. Synity is demo one."
#     },
#     {
#       "start_time": 165.99659375000002,
#       "end_time": 166.03034375000001,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 166.04721875,
#       "end_time": 166.06409375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 166.50284375,
#       "end_time": 167.59971875000002,
#       "speaker": "SPEAKER_00",
#       "text": " from Friday."
#     },
#     {
#       "start_time": 167.88659375,
#       "end_time": 167.90346875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 171.21096875,
#       "end_time": 178.43346875,
#       "speaker": "SPEAKER_00",
#       "text": " By the way, I was going to ask, I had seen the video, you did a down something of the video, right? I mean..."
#     },
#     {
#       "start_time": 180.40784375,
#       "end_time": 182.87159375000002,
#       "speaker": "SPEAKER_00",
#       "text": " for browsing. I mean, yeah. Okay. Yeah."
#     },
#     {
#       "start_time": 187.42784375000002,
#       "end_time": 189.01409375,
#       "speaker": "SPEAKER_01",
#       "text": " So this was the..."
#     },
#     {
#       "start_time": 191.17409375000003,
#       "end_time": 191.62971875000002,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 191.86596875,
#       "end_time": 196.30409375000002,
#       "speaker": "SPEAKER_00",
#       "text": " So, if you see the hierarchy, call normally so you have scenes, shots. Yeah, here."
#     },
#     {
#       "start_time": 195.69659375,
#       "end_time": 200.64096875,
#       "speaker": "SPEAKER_01",
#       "text": " Here on the left you have different scenes, but as I have noticed..."
#     },
#     {
#       "start_time": 199.40909375,
#       "end_time": 208.82534375,
#       "speaker": "SPEAKER_00",
#       "text": " As I was going to say, we could probably, you know, like group or the initial ones into one scene and maybe after when there's some things inside, it should be another scene."
#     },
#     {
#       "start_time": 209.53409375,
#       "end_time": 225.64971875,
#       "speaker": "SPEAKER_01",
#       "text": " So this detector detected 30 shots and if you click on a plus button you can expand it and see the key frames that are in fact 5 extracted frames from the shot."
#     },
#     {
#       "start_time": 219.10221875000002,
#       "end_time": 219.40596875000003,
#       "speaker": "SPEAKER_00",
#       "text": " Money."
#     },
#     {
#       "start_time": 225.88596875000002,
#       "end_time": 227.70846875,
#       "speaker": "SPEAKER_00",
#       "text": " which I expect that I can make it."
#     },
#     {
#       "start_time": 225.91971875000002,
#       "end_time": 226.56096875,
#       "speaker": "SPEAKER_01",
#       "text": " Much registral."
#     },
#     {
#       "start_time": 226.88159375,
#       "end_time": 226.91534375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 227.70846875,
#       "end_time": 248.46471875,
#       "speaker": "SPEAKER_01",
#       "text": " but I think as it is it's extracted without using subshots it's simply five down some, yeah, down some thing. So we can see the video actually the entire video going to open with your player. I hope it will work."
#     },
#     {
#       "start_time": 227.74221875,
#       "end_time": 227.75909375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 227.77596875,
#       "end_time": 227.79284375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 237.02346875,
#       "end_time": 237.41159375,
#       "speaker": "SPEAKER_00",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 242.74409375000002,
#       "end_time": 243.04784375000003,
#       "speaker": "SPEAKER_00",
#       "text": " Good internet."
#     },
#     {
#       "start_time": 255.23159375000003,
#       "end_time": 264.51284375,
#       "speaker": "SPEAKER_01",
#       "text": " So we don't have the sound and it won't be grabbed. The video won't... I don't know if..."
#     },
#     {
#       "start_time": 265.00221875,
#       "end_time": 265.03596875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 265.59284375000004,
#       "end_time": 265.72784375000003,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 265.76159375000003,
#       "end_time": 267.55034375,
#       "speaker": "SPEAKER_01",
#       "text": " Okay, that's good quality."
#     },
#     {
#       "start_time": 268.07346875,
#       "end_time": 269.35596875000005,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, the quality too."
#     },
#     {
#       "start_time": 269.50784375,
#       "end_time": 274.67159375,
#       "speaker": "SPEAKER_00",
#       "text": " That's why I was asking that. Oh yeah, yeah. It's not this that you process. No, no, no, no, no, no, no, no. Okay."
#     },
#     {
#       "start_time": 271.33034375,
#       "end_time": 277.92846875000004,
#       "speaker": "SPEAKER_01",
#       "text": " It's not this that you process. No, no, no, no. It's in real media, so it's very compressed. So here is."
#     },
#     {
#       "start_time": 277.38846875,
#       "end_time": 288.50909375000003,
#       "speaker": "SPEAKER_00",
#       "text": " So here we see that we are the SOPA at 18th and after 22th and after again. And if we go down, I mean maybe in terms of shot here, we can see that."
#     },
#     {
#       "start_time": 283.68284375,
#       "end_time": 283.95284375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 286.48409375,
#       "end_time": 286.66971875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 290.02784375000005,
#       "end_time": 294.39846875,
#       "speaker": "SPEAKER_00",
#       "text": " Right, I mean, maybe C-Shot 7, I suppose."
#     },
#     {
#       "start_time": 300.03096875,
#       "end_time": 300.57096875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 302.98409375,
#       "end_time": 307.16909375,
#       "speaker": "SPEAKER_01",
#       "text": " We ordered nine from the\u6392."
#     },
#     {
#       "start_time": 303.91221875,
#       "end_time": 304.03034375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 308.99159375,
#       "end_time": 315.01596875,
#       "speaker": "SPEAKER_01",
#       "text": " 11 or 12 no 11 10 this is 10 in 10 okay"
#     },
#     {
#       "start_time": 312.46784375,
#       "end_time": 314.84721875,
#       "speaker": "SPEAKER_00",
#       "text": " So there is an effort"
#     },
#     {
#       "start_time": 315.01596875,
#       "end_time": 316.53471875,
#       "speaker": "SPEAKER_00",
#       "text": " and then do the..."
#     },
#     {
#       "start_time": 316.53471875,
#       "end_time": 320.88846875,
#       "speaker": "SPEAKER_01",
#       "text": " yeah this one it's 11 okay 12"
#     },
#     {
#       "start_time": 317.69909375,
#       "end_time": 317.88471875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 322.45784375,
#       "end_time": 323.85846875,
#       "speaker": "SPEAKER_01",
#       "text": " 14 seconds."
#     },
#     {
#       "start_time": 327.97596875,
#       "end_time": 328.38096875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 330.62534375,
#       "end_time": 341.35784375000003,
#       "speaker": "SPEAKER_01",
#       "text": " Yes, and this one, it's a dissolve, so it doesn't detect. Is it detect?"
#     },
#     {
#       "start_time": 332.21159375,
#       "end_time": 343.90596875,
#       "speaker": "SPEAKER_00",
#       "text": " Yes. And this one, it's a dissolve, it's a dissolve, so it doesn't detect. It detects. When I saw them with the employer, it's a dissolve."
#     },
#     {
#       "start_time": 341.72909375,
#       "end_time": 341.77971875000003,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 342.85971875,
#       "end_time": 343.21409375,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 347.36534375,
#       "end_time": 364.27409375,
#       "speaker": "SPEAKER_01",
#       "text": " But it's not stand out many movies because I would say most of the time people didn't do any dessert. Yeah, I could see here and I thought it was like, or it was only one thing."
#     },
#     {
#       "start_time": 354.48659375,
#       "end_time": 354.80721875,
#       "speaker": "SPEAKER_00",
#       "text": " P."
#     },
#     {
#       "start_time": 360.74721875,
#       "end_time": 370.43346875,
#       "speaker": "SPEAKER_00",
#       "text": " I'm going to put it on the one thing. I don't know if this one, if we see what's correctly... You see? Yeah, yeah."
#     },
#     {
#       "start_time": 369.70784375,
#       "end_time": 382.70159375000003,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, yeah, this is the one I had seen. Yeah, but as I said, I mean, we've had the motion detector when it's black, there's no structures. But there is a moon, but you don't really estimate motion. Okay, because..."
#     },
#     {
#       "start_time": 378.95534375,
#       "end_time": 385.04721875,
#       "speaker": "SPEAKER_00",
#       "text": " But there is a moon, but you don't have to estimate motion. Okay, because there is no motion in fact between two shots."
#     },
#     {
#       "start_time": 384.43971875,
#       "end_time": 396.47159375,
#       "speaker": "SPEAKER_01",
#       "text": " There is no texture. There is no texture. This is not so good for the motion. But for instance, of course, between the horse and..."
#     },
#     {
#       "start_time": 387.54471875,
#       "end_time": 388.70909375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, you're okay, it's okay."
#     },
#     {
#       "start_time": 397.65284375,
#       "end_time": 414.35909375,
#       "speaker": "SPEAKER_01",
#       "text": " The... yeah. That is a Q. The Co. The Co. Maybe we could have detected things. But it's not even sure because you see the background is quite similar and it's not that sure."
#     },
#     {
#       "start_time": 404.16659375,
#       "end_time": 404.77409375,
#       "speaker": "SPEAKER_00",
#       "text": " the coil"
#     },
#     {
#       "start_time": 404.85846875,
#       "end_time": 404.95971875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 405.33096875,
#       "end_time": 405.66846875,
#       "speaker": "SPEAKER_00",
#       "text": " and"
#     },
#     {
#       "start_time": 409.09409375,
#       "end_time": 409.49909375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 414.35909375,
#       "end_time": 428.38221875,
#       "speaker": "SPEAKER_00",
#       "text": " Maybe to explain this method was using a simple distance between consecutive histograms. And we didn't use motion features at all for that. That's why you..."
#     },
#     {
#       "start_time": 423.47159375,
#       "end_time": 423.87659375,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 426.17159375,
#       "end_time": 426.52596875,
#       "speaker": "SPEAKER_01",
#       "text": " Hmm."
#     },
#     {
#       "start_time": 428.02784375,
#       "end_time": 472.69596875,
#       "speaker": "SPEAKER_01",
#       "text": " So it's yeah, and there's your Instagram, so you experience a bit. So it's crampers, so you can scramble the image. And you get the same Instagram. So there is no structure. So of course, when you look the horse, and then you could see the cows. Of course, you have a black in the top. And we have also maybe a tip a cent of green, which is not green there, but grass. You have stones, and so there are of course some differences, because on one hand you have horse, but it's black. So you have more sky, which is black on the right. So you don't care about this. So it's global, it's a global Instagram."
#     },
#     {
#       "start_time": 431.20034375,
#       "end_time": 432.55034375,
#       "speaker": "SPEAKER_00",
#       "text": " experience a bit."
#     },
#     {
#       "start_time": 436.83659375,
#       "end_time": 437.25846875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 439.09784375000004,
#       "end_time": 439.38471875000005,
#       "speaker": "SPEAKER_00",
#       "text": " Yes."
#     },
#     {
#       "start_time": 441.00471875,
#       "end_time": 441.35909375,
#       "speaker": "SPEAKER_00",
#       "text": " game."
#     },
#     {
#       "start_time": 453.50909375000003,
#       "end_time": 453.88034375,
#       "speaker": "SPEAKER_00",
#       "text": " Even back"
#     },
#     {
#       "start_time": 467.70096875,
#       "end_time": 468.13971875000004,
#       "speaker": "SPEAKER_00",
#       "text": " You know."
#     },
#     {
#       "start_time": 472.83096875,
#       "end_time": 473.01659374999997,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 473.40471875000003,
#       "end_time": 473.69159375000004,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 475.88534375,
#       "end_time": 487.29284375,
#       "speaker": "SPEAKER_01",
#       "text": " But it's when for this time with the for this application I could imagine that it would be in a fight and And it's a threshold, but still it's adaptive. Yeah, I remember. Yeah"
#     },
#     {
#       "start_time": 480.28971875,
#       "end_time": 480.69471875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 485.85846875000004,
#       "end_time": 490.22909375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, yeah, with a sliding window."
#     },
#     {
#       "start_time": 489.04784374999997,
#       "end_time": 489.38534375,
#       "speaker": "SPEAKER_01",
#       "text": " No."
#     },
#     {
#       "start_time": 490.02659375,
#       "end_time": 490.19534375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 490.22909375,
#       "end_time": 543.21659375,
#       "speaker": "SPEAKER_01",
#       "text": " Because of course if you just compute the... Yeah, if you just report. Because if you compute the distance between the two histograms, I think this was Bata-Sharia. Right? And so if you take these two with the Bata-Sharia, then of course you should just do a threshold. When there is motion, you will see a lot of things changing. So by using an adaptive threshold, if you see that there is a continuous change of the distance, you don't do a threshold. It's only if you have an identified peak, which is 50%, or maybe two times higher than the next second value in the window, then you see it's a shot. Yeah."
#     },
#     {
#       "start_time": 493.92471875,
#       "end_time": 495.02159375,
#       "speaker": "SPEAKER_00",
#       "text": " I'm gonna show you..."
#     },
#     {
#       "start_time": 501.80534375,
#       "end_time": 501.97409375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 502.83471875,
#       "end_time": 505.19721875000005,
#       "speaker": "SPEAKER_00",
#       "text": " Oh no, you're not."
#     },
#     {
#       "start_time": 519.30471875,
#       "end_time": 519.79409375,
#       "speaker": "SPEAKER_00",
#       "text": " So bye."
#     },
#     {
#       "start_time": 528.99096875,
#       "end_time": 529.42971875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 541.39409375,
#       "end_time": 599.96721875,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, I don't know if we want to make use the whiteboard or here it was to this it's in only the this part about the shot wonder detection is in French and fraternately but the this image shows the results using motion when you use the motion features and here on the right is when using the histogram distance and the the motion features can better show what's going on when there is such a difficult transition while with the histogram you just show that there is a shot change at the end but even for dissolves I don't have examples here but there is not a strict transition"
#     },
#     {
#       "start_time": 553.7297187500001,
#       "end_time": 554.32034375,
#       "speaker": "SPEAKER_01",
#       "text": " But"
#     },
#     {
#       "start_time": 573.81096875,
#       "end_time": 574.01346875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 598.66784375,
#       "end_time": 599.0053437500001,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 600.03096875,
#       "end_time": 695.27346875,
#       "speaker": "SPEAKER_01",
#       "text": " Continuous for this Earth. But this Earth is... Anyway, it's difficult, I mean, in general, because sometimes there are some dissolve. You could imagine they are part of a scene. But of course, when you have cuts, you can see they are easy to detect, right? I mean, like... Yeah. So... Yeah, so with the motion, basically the motion tried to estimate what's the motion between two frames, right? If it may image is there, but after it's there, and it looks at how many points are well matched. Okay. So you can see that, like somebody speaking and so on, so before the shot, you can see that usually there are like 90% of the points, at least, right? There's some motion, so... But then, after suddenly, if you go from one frame and you try too much, all the points here, we've like a translation, plus a zoom, plus maybe some rotation, you can't find anything well. So basically, you see that the number of points, maybe only 10% of the points you can match well. So it's easy to detect. And after you can see that indeed, because it's a long shot, and it's almost like a flat plane, you can do a very good registration so the number of points is very high. I mean, the number of points that are matching. And here you basically hear with the histogram. You can see it's very flat, but of course, you should go from this histogram to this, which is essentially green. You have this thickness, a measure, which is here, the kite too. I don't know whether this is what you implement easiest. No, no."
#     },
#     {
#       "start_time": 600.65534375,
#       "end_time": 605.11034375,
#       "speaker": "SPEAKER_00",
#       "text": " is continuous for this Earth. But this Earth is... Any..."
#     },
#     {
#       "start_time": 605.12721875,
#       "end_time": 605.14409375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 615.13409375,
#       "end_time": 615.42096875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 619.80846875,
#       "end_time": 620.44971875,
#       "speaker": "SPEAKER_00",
#       "text": " in"
#     },
#     {
#       "start_time": 624.58409375,
#       "end_time": 624.90471875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 629.24159375,
#       "end_time": 629.62971875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 634.77659375,
#       "end_time": 635.26596875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 643.60221875,
#       "end_time": 643.99034375,
#       "speaker": "SPEAKER_00",
#       "text": " Silvete's right manual"
#     },
#     {
#       "start_time": 652.56284375,
#       "end_time": 652.83284375,
#       "speaker": "SPEAKER_00",
#       "text": " Enjoy watching!"
#     },
#     {
#       "start_time": 654.50346875,
#       "end_time": 655.43159375,
#       "speaker": "SPEAKER_00",
#       "text": " Tradition you."
#     },
#     {
#       "start_time": 655.53284375,
#       "end_time": 656.79846875,
#       "speaker": "SPEAKER_00",
#       "text": " You can't find anything well."
#     },
#     {
#       "start_time": 656.98409375,
#       "end_time": 657.42284375,
#       "speaker": "SPEAKER_00",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 662.36721875,
#       "end_time": 662.82284375,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 671.24346875,
#       "end_time": 671.49659375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 674.28096875,
#       "end_time": 676.84596875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay. It's very high, I mean, the number of points at all."
#     },
#     {
#       "start_time": 688.11846875,
#       "end_time": 688.92846875,
#       "speaker": "SPEAKER_00",
#       "text": " Oh..."
#     },
#     {
#       "start_time": 694.3959687500001,
#       "end_time": 699.54284375,
#       "speaker": "SPEAKER_00",
#       "text": " No, no, no. Now it's for the video you saw it's Batashai."
#     },
#     {
#       "start_time": 699.27284375,
#       "end_time": 700.67346875,
#       "speaker": "SPEAKER_01",
#       "text": " and something like that."
#     },
#     {
#       "start_time": 700.99409375,
#       "end_time": 701.01096875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 701.01096875,
#       "end_time": 701.44971875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 702.39471875,
#       "end_time": 711.86159375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, so yeah, and you have maybe one image with an adaptive threshold. I think you had something like this. Just to explain."
#     },
#     {
#       "start_time": 708.50346875,
#       "end_time": 708.85784375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 711.86159375,
#       "end_time": 715.33784375,
#       "speaker": "SPEAKER_00",
#       "text": " Okay, it's at the beginning."
#     },
#     {
#       "start_time": 717.36284375,
#       "end_time": 718.39221875,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, we should look here."
#     },
#     {
#       "start_time": 721.22721875,
#       "end_time": 725.83409375,
#       "speaker": "SPEAKER_00",
#       "text": " So the idea is having a sliding window."
#     },
#     {
#       "start_time": 725.85096875,
#       "end_time": 752.29409375,
#       "speaker": "SPEAKER_00",
#       "text": " We have already all the data that is on the graph. And then to detect the changes, we do a calculation with points under this sliding window within this sliding window. And we calculate, so what do we do here?"
#     },
#     {
#       "start_time": 725.86784375,
#       "end_time": 725.95221875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 732.17909375,
#       "end_time": 732.24659375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 745.89846875,
#       "end_time": 746.01659375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 754.28534375,
#       "end_time": 762.50346875,
#       "speaker": "SPEAKER_00",
#       "text": " In fact, we want to detect that this point in the middle is higher than..."
#     },
#     {
#       "start_time": 765.11909375,
#       "end_time": 771.85221875,
#       "speaker": "SPEAKER_01",
#       "text": " Half that time the maximum of the other ones, exactly the other ones. Half that time the maximum of the other ones."
#     },
#     {
#       "start_time": 765.37221875,
#       "end_time": 765.5578437500001,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 767.43096875,
#       "end_time": 771.91971875,
#       "speaker": "SPEAKER_00",
#       "text": " the other ones, exactly the other ones, and for the time being the maximum of the other ones."
#     },
#     {
#       "start_time": 771.91971875,
#       "end_time": 771.93659375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 771.93659375,
#       "end_time": 771.97034375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 771.97034375,
#       "end_time": 772.03784375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 772.05471875,
#       "end_time": 788.00159375,
#       "speaker": "SPEAKER_01",
#       "text": " So of course if it's you are not a maximum, you are not going inside the window, you are not the max. Anyway, you are not going to be above alpha times the max of the others, right? Because alpha is lower than one."
#     },
#     {
#       "start_time": 781.21784375,
#       "end_time": 781.36971875,
#       "speaker": "SPEAKER_00",
#       "text": " the"
#     },
#     {
#       "start_time": 784.5422187500001,
#       "end_time": 785.01471875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 787.69784375,
#       "end_time": 800.91096875,
#       "speaker": "SPEAKER_00",
#       "text": " But if you are in the maximum already at this point, we check simply if this value is alpha times the max of the other points. Let's say this point here."
#     },
#     {
#       "start_time": 797.45159375,
#       "end_time": 797.50221875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 799.66221875,
#       "end_time": 800.94471875,
#       "speaker": "SPEAKER_01",
#       "text": " And let's say at this point here."
#     },
#     {
#       "start_time": 801.19784375,
#       "end_time": 807.28971875,
#       "speaker": "SPEAKER_01",
#       "text": " I feel like I see 6 but I don't know whether this was for Batacharya or for... Okay."
#     },
#     {
#       "start_time": 801.68721875,
#       "end_time": 803.07096875,
#       "speaker": "SPEAKER_00",
#       "text": " That's your AC6."
#     },
#     {
#       "start_time": 807.39096875,
#       "end_time": 819.10221875,
#       "speaker": "SPEAKER_00",
#       "text": " It may be for kids, 6 but for the tests I did 2.4."
#     },
#     {
#       "start_time": 817.63409375,
#       "end_time": 867.7865937500001,
#       "speaker": "SPEAKER_01",
#       "text": " I did it 2.4. 2.4, yeah. So it's a bit less because you amplitude it much. Yeah. Yeah. Don't, yeah. So you can, it was not so obvious. I mean, because the ocean, I mean, it was in the shot we've seen, because especially with Kite to square it, the amplitude it's much bigger than with Bata-Sharia. Right? You can see that it could go to 700. And when it's very nothing, it can be zero. What's Bata-Sharia is between zero and one. So you have not so much amplitude. But still, in some of these videos, for instance, even if we're going to go now, if we want to go now, for the kayak kids, I don't know. At some point, he's targeting two kayaks and he's moving quite fast to what's to other people. I don't know what happened there. If it was detected as a shot, I don't know. Yeah."
#     },
#     {
#       "start_time": 822.29159375,
#       "end_time": 823.03409375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 823.27034375,
#       "end_time": 823.67534375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 823.69221875,
#       "end_time": 823.70909375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 825.26159375,
#       "end_time": 825.5990937500001,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 829.37909375,
#       "end_time": 829.85159375,
#       "speaker": "SPEAKER_00",
#       "text": " comes"
#     },
#     {
#       "start_time": 837.78284375,
#       "end_time": 838.64346875,
#       "speaker": "SPEAKER_00",
#       "text": " Right."
#     },
#     {
#       "start_time": 841.34346875,
#       "end_time": 841.66409375,
#       "speaker": "SPEAKER_00",
#       "text": " and win."
#     },
#     {
#       "start_time": 846.54096875,
#       "end_time": 847.03034375,
#       "speaker": "SPEAKER_00",
#       "text": " That's so much."
#     },
#     {
#       "start_time": 866.45346875,
#       "end_time": 877.15221875,
#       "speaker": "SPEAKER_00",
#       "text": " In the first shot? Yeah, I saw that he was detected as a shot. As a shot, okay. I was the one that we wanted to see now. Yeah, maybe. But he didn't, okay."
#     },
#     {
#       "start_time": 869.3559687500001,
#       "end_time": 871.19534375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, yeah. Yeah, I saw that tutorial directly."
#     },
#     {
#       "start_time": 871.26284375,
#       "end_time": 871.27971875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 871.4653437500001,
#       "end_time": 876.9328437500001,
#       "speaker": "SPEAKER_01",
#       "text": " As the shot, as the shot, okay. I was the one that wanted me to see. You want to see now? Okay. Yeah, maybe. But he didn't, okay."
#     },
#     {
#       "start_time": 877.15221875,
#       "end_time": 898.0265937500001,
#       "speaker": "SPEAKER_01",
#       "text": " But here friends as you understand so we can show this tomorrow to To the people at the city in it is meeting him into Yeah, yeah, yeah, we need a connection that's true And that's laptop or you have yeah, I can bring my laptop if necessary. Yeah, yeah, I'll bring it. Okay. Okay"
#     },
#     {
#       "start_time": 882.1303437500001,
#       "end_time": 883.71659375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, because in that it's meeting."
#     },
#     {
#       "start_time": 884.27346875,
#       "end_time": 884.84721875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 885.13409375,
#       "end_time": 885.96096875,
#       "speaker": "SPEAKER_00",
#       "text": " VIP"
#     },
#     {
#       "start_time": 887.56409375,
#       "end_time": 889.57221875,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, okay, yeah, we need a connection, that's true."
#     },
#     {
#       "start_time": 889.7409687500001,
#       "end_time": 889.96034375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 889.99409375,
#       "end_time": 890.0109687500001,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 890.95596875,
#       "end_time": 894.75284375,
#       "speaker": "SPEAKER_00",
#       "text": " And is it the laptop or you have you? Yeah, I can bring my laptop if."
#     },
#     {
#       "start_time": 894.87096875,
#       "end_time": 899.96721875,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, I bring it. Okay. Okay. It's done. This is it."
#     },
#     {
#       "start_time": 900.03096875,
#       "end_time": 911.10096875,
#       "speaker": "SPEAKER_01",
#       "text": " So here in fact after 12 I don't know if it's I think it's 12 frames"
#     },
#     {
#       "start_time": 902.20784375,
#       "end_time": 902.44409375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 911.18534375,
#       "end_time": 916.07909375,
#       "speaker": "SPEAKER_00",
#       "text": " Oh yeah, but normally very so, burning. If you... maybe you can play the shot."
#     },
#     {
#       "start_time": 912.41721875,
#       "end_time": 913.41284375,
#       "speaker": "SPEAKER_01",
#       "text": " He refers to the\uc6b0"
#     },
#     {
#       "start_time": 916.70346875,
#       "end_time": 916.97346875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 917.88471875,
#       "end_time": 919.60596875,
#       "speaker": "SPEAKER_00",
#       "text": " Strange. Oh yeah maybe a burning."
#     },
#     {
#       "start_time": 918.37409375,
#       "end_time": 919.77471875,
#       "speaker": "SPEAKER_01",
#       "text": " I am maybe a burning man."
#     },
#     {
#       "start_time": 919.77471875,
#       "end_time": 922.37346875,
#       "speaker": "SPEAKER_00",
#       "text": " maybe play a few plays uh"
#     },
#     {
#       "start_time": 923.58846875,
#       "end_time": 926.84534375,
#       "speaker": "SPEAKER_00",
#       "text": " the video when it's at the beginning I don't know what's up"
#     },
#     {
#       "start_time": 926.67659375,
#       "end_time": 937.74659375,
#       "speaker": "SPEAKER_01",
#       "text": " I don't have time to win the game. But it's complicated."
#     },
#     {
#       "start_time": 931.19909375,
#       "end_time": 934.69221875,
#       "speaker": "SPEAKER_00",
#       "text": " I have a timeline door with a media"
#     },
#     {
#       "start_time": 938.01659375,
#       "end_time": 970.92284375,
#       "speaker": "SPEAKER_00",
#       "text": " Well, no, I mean, here I can see that it was detected as a single shot. Yeah, here we can see that. Okay. I was because here you can see that the motion, here is there, you know, is there doing a zoom on the two. Yeah. Kayak. And then there is translation. Yeah. And then he's doing quite a fast transition from this to another one. Okay. And I was wondering whether, so if you, well, of course, it's true that it's mainly water. So maybe the color is indeed quite. But, you know, as Kayak is entering quite fast, I mean, you can have quite a minute."
#     },
#     {
#       "start_time": 942.50534375,
#       "end_time": 944.19284375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, here we can see that."
#     },
#     {
#       "start_time": 946.11659375,
#       "end_time": 946.84221875,
#       "speaker": "SPEAKER_01",
#       "text": " Oh, I think they're completely lost in there."
#     },
#     {
#       "start_time": 948.81659375,
#       "end_time": 949.98096875,
#       "speaker": "SPEAKER_01",
#       "text": " Doing a zoom on the"
#     },
#     {
#       "start_time": 950.43659375,
#       "end_time": 950.79096875,
#       "speaker": "SPEAKER_01",
#       "text": " You"
#     },
#     {
#       "start_time": 951.06096875,
#       "end_time": 953.28846875,
#       "speaker": "SPEAKER_01",
#       "text": " And then there is translation."
#     },
#     {
#       "start_time": 956.56221875,
#       "end_time": 957.45659375,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 969.04971875,
#       "end_time": 969.26909375,
#       "speaker": "SPEAKER_01",
#       "text": " again."
#     },
#     {
#       "start_time": 970.92284375,
#       "end_time": 974.24721875,
#       "speaker": "SPEAKER_01",
#       "text": " I can see there is another program that can see you."
#     },
#     {
#       "start_time": 973.52159375,
#       "end_time": 976.59284375,
#       "speaker": "SPEAKER_00",
#       "text": " I am sure it seems to be how many shots do you have indeed."
#     },
#     {
#       "start_time": 977.04846875,
#       "end_time": 978.75284375,
#       "speaker": "SPEAKER_01",
#       "text": "process out the"
#     },
#     {
#       "start_time": 980.42346875,
#       "end_time": 983.19096875,
#       "speaker": "SPEAKER_01",
#       "text": " I think there are five of them."
#     },
#     {
#       "start_time": 983.14034375,
#       "end_time": 991.67909375,
#       "speaker": "SPEAKER_00",
#       "text": " Yes, the one is, if we expand all. So you did it with what, by the way. It's with the images I gave you. Yeah. OK."
#     },
#     {
#       "start_time": 984.22034375,
#       "end_time": 986.00909375,
#       "speaker": "SPEAKER_01",
#       "text": " if we would expand or..."
#     },
#     {
#       "start_time": 990.97034375,
#       "end_time": 1056.0234687500001,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, okay. The other one had problems converting the video into DVIX. And then, so I use the program from software from Sebastian PPM to API. To API, okay. Because yeah, one thing maybe we will talk about that is the library. It's, it doesn't compile anymore on DBN machines. Yeah, so maybe some work has to be done on this. I don't know why this image doesn't appear. This is the the frame that is extracted to be the shot keyframe here. This one is this one, the middle one. So I don't know why it doesn't appear, but it's just a simple problem in the getframe. But what I can show you now is a little program if you want to be very precise about. So it's get frames."
#     },
#     {
#       "start_time": 999.52596875,
#       "end_time": 1000.84221875,
#       "speaker": "SPEAKER_00",
#       "text": " I'd really never been using the computer tools in my moments of wheel testing video because I don't have a concrete sort ofances because of the technology that I put through against. I can't allow the advanced model to get fully literate computers in your phone. I could have a screen"
#     },
#     {
#       "start_time": 1006.66409375,
#       "end_time": 1009.83659375,
#       "speaker": "SPEAKER_00",
#       "text": " Are to assist toast three okay"
#     },
#     {
#       "start_time": 1021.27784375,
#       "end_time": 1021.63221875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 1064.10659375,
#       "end_time": 1066.65471875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay, see you next time."
#     },
#     {
#       "start_time": 1069.70909375,
#       "end_time": 1077.13409375,
#       "speaker": "SPEAKER_01",
#       "text": " and we were interested in around, what do you want? Around six, seven seconds."
#     },
#     {
#       "start_time": 1077.85971875,
#       "end_time": 1081.31909375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, I mean initially I don't know why there is a shot detected."
#     },
#     {
#       "start_time": 1081.55534375,
#       "end_time": 1085.08221875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay, if we do rain next."
#     },
#     {
#       "start_time": 1086.60096875,
#       "end_time": 1093.16534375,
#       "speaker": "SPEAKER_01",
#       "text": " Oh, are you? No, there is something wrong. Oh, okay, so see you. Okay."
#     },
#     {
#       "start_time": 1088.87909375,
#       "end_time": 1090.71846875,
#       "speaker": "SPEAKER_00",
#       "text": " What? You're the same thing, won't you?"
#     },
#     {
#       "start_time": 1091.42721875,
#       "end_time": 1096.05096875,
#       "speaker": "SPEAKER_00",
#       "text": " Oh, okay, so the 0.0.2 here is an image number."
#     },
#     {
#       "start_time": 1096.54034375,
#       "end_time": 1102.78409375,
#       "speaker": "SPEAKER_00",
#       "text": " In fact, yeah, that's what I said. It's a frame number. I don't know why. Yeah, yeah, yeah. It's a frame number."
#     },
#     {
#       "start_time": 1096.62471875,
#       "end_time": 1106.66534375,
#       "speaker": "SPEAKER_01",
#       "text": " In fact, yeah, that's what I said. It's a frame number. I don't know why. Yeah, yeah, yeah. It's a frame number. Okay, so this is the frame number. This is in second, but I kept the frame number."
#     },
#     {
#       "start_time": 1106.42909375,
#       "end_time": 1109.88846875,
#       "speaker": "SPEAKER_00",
#       "text": " So you have to say 0.2, it's 10 seconds already."
#     },
#     {
#       "start_time": 1109.6015937500001,
#       "end_time": 1112.62221875,
#       "speaker": "SPEAKER_01",
#       "text": " It's 12 frames, zero seconds."
#     },
#     {
#       "start_time": 1111.77846875,
#       "end_time": 1112.41971875,
#       "speaker": "SPEAKER_00",
#       "text": " Zero seconds."
#     },
#     {
#       "start_time": 1113.78659375,
#       "end_time": 1123.6753437500001,
#       "speaker": "SPEAKER_00",
#       "text": " Okay, yeah, okay, okay seconds plus No, the next is 11 seconds Okay, so basically what has been Yeah, extracted is at this point or other bend Okay, so this is normal Yeah"
#     },
#     {
#       "start_time": 1114.02284375,
#       "end_time": 1114.27596875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 1116.23346875,
#       "end_time": 1119.3047187500001,
#       "speaker": "SPEAKER_01",
#       "text": " No, the next is 11 seconds. Okay, so basically what?"
#     },
#     {
#       "start_time": 1122.34221875,
#       "end_time": 1134.79596875,
#       "speaker": "SPEAKER_01",
#       "text": " So this is normal. Yeah. So if we do every second, the middle frame is this 1000."
#     },
#     {
#       "start_time": 1139.68971875,
#       "end_time": 1158.35346875,
#       "speaker": "SPEAKER_01",
#       "text": " Just another kind of browsing page, but to be more precise, to check maybe this Yeah, exactly, yeah, then you go back to one frame around 160 for instance"
#     },
#     {
#       "start_time": 1148.80221875,
#       "end_time": 1152.09284375,
#       "speaker": "SPEAKER_00",
#       "text": " You dialect. So yeah, exactly, yeah, yeah."
#     },
#     {
#       "start_time": 1160.29409375,
#       "end_time": 1164.27659375,
#       "speaker": "SPEAKER_01",
#       "text": " And there is... Yeah, that's it."
#     },
#     {
#       "start_time": 1161.84659375,
#       "end_time": 1164.22596875,
#       "speaker": "SPEAKER_00",
#       "text": " Okay. Yeah, that sounds okay."
#     },
#     {
#       "start_time": 1164.96846875,
#       "end_time": 1164.98534375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 1165.05284375,
#       "end_time": 1165.74471875,
#       "speaker": "SPEAKER_01",
#       "text": " Prev."
#     },
#     {
#       "start_time": 1165.94721875,
#       "end_time": 1172.12346875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay, you see that there is... Okay, it's not a short change, it's a motion actually here."
#     },
#     {
#       "start_time": 1172.25846875,
#       "end_time": 1172.29221875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 1172.29221875,
#       "end_time": 1199.96721875,
#       "speaker": "SPEAKER_00",
# ...
#       "text": ""
#     },
#     {
#       "start_time": 3083.56221875,
#       "end_time": 3083.71409375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 3089.40096875,
#       "end_time": 3090.78471875,
#       "speaker": "SPEAKER_02",
#       "text": " for being"
#     },
#     {
#       "start_time": 3093.72096875,
#       "end_time": 3094.17659375,
#       "speaker": "SPEAKER_02",
#       "text": " Let me see."
#     },
#     {
#       "start_time": 3098.51346875,
#       "end_time": 3099.50909375,
#       "speaker": "SPEAKER_02",
#       "text": " Okay, ready."
#     },
#     {
#       "start_time": 3103.50846875,
#       "end_time": 3109.48221875,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, very , err.. \u2013sticks producer \u2013 \u2013and that's it you can eat See the world"
#     },
#     {
#       "start_time": 3106.86659375,
#       "end_time": 3111.70971875,
#       "speaker": "SPEAKER_02",
#       "text": " You need to have windows to make this."
#     },
#     {
#       "start_time": 3112.72221875,
#       "end_time": 3113.11034375,
#       "speaker": "SPEAKER_00",
#       "text": " Yes."
#     },
#     {
#       "start_time": 3113.54909375,
#       "end_time": 3118.96596875,
#       "speaker": "SPEAKER_02",
#       "text": " So, I will ask you. Yeah."
#     },
#     {
#       "start_time": 3115.42221875,
#       "end_time": 3121.07534375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah. Yeah. Yeah. Yeah. Yeah. Yeah."
#     },
#     {
#       "start_time": 3121.00784375,
#       "end_time": 3122.56034375,
#       "speaker": "SPEAKER_02",
#       "text": " Okay, okay, understand."
#     },
#     {
#       "start_time": 3123.60659375,
#       "end_time": 3125.71596875,
#       "speaker": "SPEAKER_00",
#       "text": " And yeah, with real media."
#     },
#     {
#       "start_time": 3124.46721875,
#       "end_time": 3129.34409375,
#       "speaker": "SPEAKER_02",
#       "text": " with real media. This is made by a program done outside the depth."
#     },
#     {
#       "start_time": 3130.54221875,
#       "end_time": 3159.87096875,
#       "speaker": "SPEAKER_00",
#       "text": " Well, you can buy or you can do it for free. Okay. It's not a job for free. No, no, no, no, for the VLMedia. And you didn't see, but the VLMedia is called VLMedia a real server. So it's RTSP, the connection. And it's streaming, video streaming. So it's not HTTP. So that it can play a smoothie. But we are still investigating for other VLMedia formats because..."
#     },
#     {
#       "start_time": 3132.55034375,
#       "end_time": 3136.93784375,
#       "speaker": "SPEAKER_02",
#       "text": " All, they were for free. One tennis. It's not a jump. No, no, no, no, for the..."
#     },
#     {
#       "start_time": 3136.93784375,
#       "end_time": 3137.00534375,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 3146.20221875,
#       "end_time": 3146.59034375,
#       "speaker": "SPEAKER_02",
#       "text": ""
#     },
#     {
#       "start_time": 3146.59034375,
#       "end_time": 3146.60721875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 3148.86846875,
#       "end_time": 3149.37471875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, it's..."
#     },
#     {
#       "start_time": 3149.50971875,
#       "end_time": 3149.57721875,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 3150.37034375,
#       "end_time": 3154.50471875,
#       "speaker": "SPEAKER_01",
#       "text": " streaming so it's not HTTP so that it can play"
#     },
#     {
#       "start_time": 3161.52471875,
#       "end_time": 3169.52346875,
#       "speaker": "SPEAKER_00",
#       "text": " It's not supported for instance in Java, in Java applications, etc."
#     },
#     {
#       "start_time": 3170.1647187500002,
#       "end_time": 3178.93971875,
#       "speaker": "SPEAKER_01",
#       "text": " Oh yeah, you mean I have a framework what might presented you cannot play"
#     },
#     {
#       "start_time": 3171.73409375,
#       "end_time": 3172.44284375,
#       "speaker": "SPEAKER_00",
#       "text": " that"
#     },
#     {
#       "start_time": 3175.59846875,
#       "end_time": 3186.21284375,
#       "speaker": "SPEAKER_00",
#       "text": " You cannot play, you know. We are media. So there are many issues about that. It's a good point. It's a good point."
#     },
#     {
#       "start_time": 3181.89284375,
#       "end_time": 3182.43284375,
#       "speaker": "SPEAKER_01",
#       "text": " Now get back into my pocket."
#     },
#     {
#       "start_time": 3185.30159375,
#       "end_time": 3186.17909375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 3186.53346875,
#       "end_time": 3186.87096875,
#       "speaker": "SPEAKER_01",
#       "text": " ok"
#     },
#     {
#       "start_time": 3187.79909375,
#       "end_time": 3205.33221875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay, so I think this was good to see the tool. Thank you. Tomorrow we are going to receive most of the things, but shorter, I believe, right? I mean, it's good to explain. And I think maybe later we can start doing it."
#     },
#     {
#       "start_time": 3190.02659375,
#       "end_time": 3190.12784375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3190.12784375,
#       "end_time": 3190.34721875,
#       "speaker": "SPEAKER_02",
#       "text": " Okay."
#     },
#     {
#       "start_time": 3190.34721875,
#       "end_time": 3190.92096875,
#       "speaker": "SPEAKER_00",
#       "text": " Jesus."
#     },
#     {
#       "start_time": 3190.97159375,
#       "end_time": 3191.02221875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3191.20784375,
#       "end_time": 3191.57909375,
#       "speaker": "SPEAKER_02",
#       "text": ""
#     },
#     {
#       "start_time": 3191.57909375,
#       "end_time": 3191.66346875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3191.66346875,
#       "end_time": 3192.00096875,
#       "speaker": "SPEAKER_02",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 3192.00096875,
#       "end_time": 3192.16971875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3198.07596875,
#       "end_time": 3199.42596875,
#       "speaker": "SPEAKER_02",
#       "text": " or VolumeVd food battle."
#     },
#     {
#       "start_time": 3199.42596875,
#       "end_time": 3199.52721875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3199.62846875,
#       "end_time": 3199.64534375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3199.64534375,
#       "end_time": 3200.01659375,
#       "speaker": "SPEAKER_02",
#       "text": "\u30e4"
#     },
#     {
#       "start_time": 3204.96096875,
#       "end_time": 3212.3522187500002,
#       "speaker": "SPEAKER_02",
#       "text": " I can take a real demo and make the full processing."
#     },
#     {
#       "start_time": 3208.03221875,
#       "end_time": 3208.53846875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 3209.97284375,
#       "end_time": 3211.49159375,
#       "speaker": "SPEAKER_01",
#       "text": " Let's see..."
#     },
#     {
#       "start_time": 3213.16221875,
#       "end_time": 3229.10909375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, I was just into Citro\u00ebn. Of course, maybe they would say, Ah, 170 shots, or... It's a lot, but... After I mean at this point, we don't... There's nothing we can do unless they know what they want to do with it."
#     },
#     {
#       "start_time": 3213.87096875,
#       "end_time": 3214.64721875,
#       "speaker": "SPEAKER_02",
#       "text": " let's go for a beer"
#     },
#     {
#       "start_time": 3219.89534375,
#       "end_time": 3220.04721875,
#       "speaker": "SPEAKER_02",
#       "text": ""
#     },
#     {
#       "start_time": 3224.28284375,
#       "end_time": 3224.68784375,
#       "speaker": "SPEAKER_02",
#       "text": ""
#     },
#     {
#       "start_time": 3228.77159375,
#       "end_time": 3228.97409375,
#       "speaker": "SPEAKER_02",
#       "text": ""
#     },
#     {
#       "start_time": 3230.71221875,
#       "end_time": 3230.9147187500002,
#       "speaker": "SPEAKER_02",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 3231.69096875,
#       "end_time": 3240.48284375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, there are other things that such as videos are doing but it's other level now. It's quite... Yeah, we're making it."
#     },
#     {
#       "start_time": 3236.77034375,
#       "end_time": 3250.60784375,
#       "speaker": "SPEAKER_01",
#       "text": " It's quite a... I think it's going very be there to be very good for them to visualize how you can organize things and maybe what they can do. And so this is important."
#     },
#     {
#       "start_time": 3244.70159375,
#       "end_time": 3244.97159375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 3250.97909375,
#       "end_time": 3267.43221875,
#       "speaker": "SPEAKER_00",
#       "text": " Last thing, this is the kind of XML that is outputted. So, the Structuring is such as a video documentation with the video scene, beginning, and then for each shot."
#     },
#     {
#       "start_time": 3264.42846875,
#       "end_time": 3265.17096875,
#       "speaker": "SPEAKER_02",
#       "text": " the beginning of this."
#     },
#     {
#       "start_time": 3267.6178437500002,
#       "end_time": 3284.29034375,
#       "speaker": "SPEAKER_00",
#       "text": " You have an ID, while this is the terms from MPAC7 convention anyway. Shot begin and end, the Shot keyframe that is the middle here. In this shot."
#     },
#     {
#       "start_time": 3267.65159375,
#       "end_time": 3268.41096875,
#       "speaker": "SPEAKER_02",
#       "text": " You have it."
#     },
#     {
#       "start_time": 3271.87034375,
#       "end_time": 3272.20784375,
#       "speaker": "SPEAKER_02",
#       "text": " with"
#     },
#     {
#       "start_time": 3281.21909375,
#       "end_time": 3287.36159375,
#       "speaker": "SPEAKER_02",
#       "text": " Okay, in this the beginning and the number is the"
#     },
#     {
#       "start_time": 3288.88034375,
#       "end_time": 3293.40284375,
#       "speaker": "SPEAKER_02",
#       "text": " For example, the end is 0.12 with a..."
#     },
#     {
#       "start_time": 3291.85034375,
#       "end_time": 3294.43221875,
#       "speaker": "SPEAKER_00",
#       "text": " 12 frames."
#     },
#     {
#       "start_time": 3294.71909375,
#       "end_time": 3296.47409375,
#       "speaker": "SPEAKER_02",
#       "text": " this frame too with you. Okay."
#     },
#     {
#       "start_time": 3297.11534375,
#       "end_time": 3299.96721875,
#       "speaker": "SPEAKER_00",
#       "text": " And in fact that's what I output."
#     },
#     {
#       "start_time": 1801.26996875,
#       "end_time": 1802.77184375,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 1802.33309375,
#       "end_time": 1810.06184375,
#       "speaker": "SPEAKER_01",
#       "text": " in under, I think under interface. And there is only one sub-trot because, yeah."
#     },
#     {
#       "start_time": 1806.43371875,
#       "end_time": 1806.72059375,
#       "speaker": "SPEAKER_00",
#       "text": " I"
#     },
#     {
#       "start_time": 1811.39496875,
#       "end_time": 1812.03621875,
#       "speaker": "SPEAKER_01",
#       "text": " Okay."
#     },
#     {
#       "start_time": 1812.20496875,
#       "end_time": 1828.40496875,
#       "speaker": "SPEAKER_01",
#       "text": " There was problems with detecting the subshots etc. But I didn't. Because you tried to do it? Yeah, I tried to call some stuff, but I'm not so confident in the way it is."
#     },
#     {
#       "start_time": 1812.5424687500001,
#       "end_time": 1813.55496875,
#       "speaker": "SPEAKER_00",
#       "text": " the worst part"
#     },
#     {
#       "start_time": 1816.32246875,
#       "end_time": 1819.54559375,
#       "speaker": "SPEAKER_00",
#       "text": " But I mean, because you tried to do it. Yeah, I tried."
#     },
#     {
#       "start_time": 1829.11371875,
#       "end_time": 1844.65559375,
#       "speaker": "SPEAKER_00",
#       "text": " Yeah, for instance, if we need to find sub-shots, usually it's better to have the whole shot to decide on how to build the sub-shots. But it shows that maybe if you store all the distances, we could do some basic stuff."
#     },
#     {
#       "start_time": 1837.55121875,
#       "end_time": 1837.93934375,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 1842.29309375,
#       "end_time": 1842.74871875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 1845.07746875,
#       "end_time": 1879.67121875,
#       "speaker": "SPEAKER_01",
#       "text": " But we, yeah, even we should, for instance, for the video, for the spectral clustering, for the clustering. Here, I store the consecutive, the distance between consecutive histograms. But we could store the matrix. Yeah, yeah, yeah, yeah. Yeah. And then, yeah. And I think there are many possible things with the spectral clustering. But there is one parameter that is very, what is the parameter?"
#     },
#     {
#       "start_time": 1861.22684375,
#       "end_time": 1866.59309375,
#       "speaker": "SPEAKER_00",
#       "text": " But we could store the matrix."
#     },
#     {
#       "start_time": 1871.38559375,
#       "end_time": 1872.71871875,
#       "speaker": "SPEAKER_00",
#       "text": " What? What?"
#     },
#     {
#       "start_time": 1879.11434375,
#       "end_time": 1882.18559375,
#       "speaker": "SPEAKER_00",
#       "text": " The second gap we made was"
#     },
#     {
#       "start_time": 1882.67496875,
#       "end_time": 1882.97871875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah."
#     },
#     {
#       "start_time": 1883.2824687500001,
#       "end_time": 1885.56059375,
#       "speaker": "SPEAKER_00",
#       "text": " Oh no, he means a better show at this time. No, no, no."
#     },
#     {
#       "start_time": 1885.13871875,
#       "end_time": 1898.84121875,
#       "speaker": "SPEAKER_01",
#       "text": " No, no, no, no. The organ gap to find the good number of clusters is so sensitive. Yeah, anyway. It's a bit later in the report."
#     },
#     {
#       "start_time": 1888.68246875,
#       "end_time": 1890.06621875,
#       "speaker": "SPEAKER_00",
#       "text": " number of plus sauces."
#     },
#     {
#       "start_time": 1894.41996875,
#       "end_time": 1894.72371875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 1901.4230937500001,
#       "end_time": 1901.82809375,
#       "speaker": "SPEAKER_00",
#       "text": " Okay."
#     },
#     {
#       "start_time": 1906.6205937500001,
#       "end_time": 1911.5480937500001,
#       "speaker": "SPEAKER_01",
#       "text": " So any time I would be happy to... I'm happy with that."
#     },
#     {
#       "start_time": 1909.21934375,
#       "end_time": 1909.53996875,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 1909.60746875,
#       "end_time": 1910.4174687500001,
#       "speaker": "SPEAKER_00",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 1911.5480937500001,
#       "end_time": 1912.1049687500001,
#       "speaker": "SPEAKER_00",
#       "text": " Thank you."
#     },
#     {
#       "start_time": 1914.93996875,
#       "end_time": 1915.36184375,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 1915.96934375,
#       "end_time": 1916.98184375,
#       "speaker": "SPEAKER_00",
#       "text": " Okay, okay."
#     },
#     {
#       "start_time": 1937.0124687500002,
#       "end_time": 1937.2824687500001,
#       "speaker": "SPEAKER_00",
#       "text": ""
#     },
#     {
#       "start_time": 1942.51371875,
#       "end_time": 1944.26871875,
#       "speaker": "SPEAKER_01",
#       "text": " Yeah, we can do it. Yeah, yeah, we can do it."
#     },
#     {
#       "start_time": 1946.22621875,
#       "end_time": 1946.2768437500001,
#       "speaker": "SPEAKER_01",
#       "text": ""
#     },
#     {
#       "start_time": 1960.2155937500002,
#       "end_time": 1965.21059375,
#       "speaker": "SPEAKER_01",
#       "text": " but everything is stored here okay I see"
#     }
#   ]
# }

# %% [markdown]
# ### Save the JSON file

# %%
output_file = '/content/drive/MyDrive/Proj/output_1.json'

with open(output_file, 'w') as json_file:
    json.dump(transcription_output, json_file, indent=2)

# %% [markdown]
# ### Another file

# %%
file_path = '/content/drive/MyDrive/Proj/IB4001.Mix-Headset.wav'
transcription_output = process_audio(file_path)

output_file = '/content/drive/MyDrive/Proj/output_2.json'

with open(output_file, 'w') as json_file:
    json.dump(transcription_output, json_file, indent=2)
# Out:
# File loaded.
# Preprocessing done.
# Breaking the file into chunks.
# Chunking done.
# Proceeding with Speaker Diarization and Transcription...
# 6it [04:29, 44.91s/it]
# 100%|██████████| 577/577 [00:00<00:00, 622457.15it/s]

# %% [markdown]
# ### Check out the accuracy

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install jiwer nltk
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.4 rapidfuzz-3.10.1

# %% [markdown]
# #### Import necessary libraries

# %%
import json
import re
from jiwer import wer
from nltk.translate.bleu_score import sentence_bleu

# %% [markdown]
# #### IN1001 audio file of AMI corpus

# %%
ref_path = '/content/drive/MyDrive/Proj/IB4001.txt'
gen_path = '/content/drive/MyDrive/Proj/output_2.json'

# %% [markdown]
# ##### Generated transcript

# %%
with open(gen_path, "r") as f:
    generated_transcript = json.load(f)["transcription"]

# %%
generated_transcript[:5]
# Out:
# [{'start_time': 6.392843750000001,
#   'end_time': 7.11846875,
#   'speaker': 'SPEAKER_01',
#   'text': ''},
#  {'start_time': 7.810343750000001,
#   'end_time': 38.30346875,
#   'speaker': 'SPEAKER_01',
#   'text': " Okay, so as you guys know, ISCO is too small. Well, the building is too small for our group. So we're moving to a new building. It's going to be the building across the street and we're actually moving in three weeks. But the problem is that the administration wants to know who's going to be in what office in the new building and where we're going to put things like the printer, the fax machine, all the big equipment. And the catch is that they have the final approval of where we put people and equipment."},
#  {'start_time': 38.69159375,
#   'end_time': 75.07409375,
#   'speaker': 'SPEAKER_01',
#   'text': " and they want to know where we're going to do all of this by November 2nd. So that means basically next Tuesday. And since we don't really have any other time, we have to make these decisions today. What we're getting is nine rooms for a maximum of 18 people, which is okay, because there's only 15 of us. And all the rooms have windows, luckily, so there's no fights about who gets a window and who doesn't. There's two views either of the old town or the mountains. And the rooms are various sizes. There's two three people rooms, five two person rooms, which are on the corners of the building. So you actually get windows on two walls."},
#  {'start_time': 50.41971875,
#   'end_time': 51.212843750000005,
#   'speaker': 'SPEAKER_00',
#   'text': ' today.'},
#  {'start_time': 76.00221875000001,
#   'end_time': 102.07409375,
#   'speaker': 'SPEAKER_01',
#   'text': " and two one-person rooms. That's pretty much what the building looks like and then you have the number of people per room. The courtyard, because we're on the sixth floor, you can't actually go out to it, but just means that the windows look out onto open space. You can see the bathrooms, the elevators are sort of further down the hall. The purple bar at the bottom, sort of on the right, is the mailboxes."}]

# %% [markdown]
# ##### Reference text

# %%
with open(ref_path, "r") as f:
    reference_text = f.read()

# %%
reference_text
# Out:
# "SPEAKER_02: Okay So as you guys know ISSCO is too small Well the building is too small for our group So we're moving to a new building Uh it's gonna be the building across the street And we're actually moving in three weeks But the problem is that the administration wants to know who is going to be in what office in the new building and where we're we're gonna put things like the printer the fax machine all the big equipment And the catch is that they have the final approval of where we put people and equipment And they want to know where we're gonna do all this by November second So that means basically next Tuesday And since we don't really have any other time we have to make these decisions today What we're getting is nine rooms for a maximum of eighteen people which is okay 'cause there's only fifteen of us And all the rooms have windows luckily so there's no fights about who gets a window and who doesn't Um there's two views either of the old town or the mountains and the rooms have various sizes There's two three people rooms five two person rooms which are on the corners of the building so you actually get windows on two walls and two one person rooms That's pretty much what the building looks like Um and then you have the number of people per room The courtyard because we're on the sixth floor you can't actually go out to it but it just means that the windows look out onto open space Um you can see the bathrooms the elevators are sort of further down the hall The purple bar at the bottom sort of on the right is the mail-boxes All of the windows open you can get out onto the terrace just like we can in our normal building And the equipment that we have to put somewhere are like I said the photocopier which is really big the fax machine which is not so big and the printer which is relatively big Each office has a white board a bulletin board and a coat rack No cupboards like we have in the current offices and each person gets their own chair their own corner desk so like the the ones that we have now um a small filing cabinet with three drawers and by small I mean they're about that.\nSPEAKER_03:Mm-hmm.\nSPEAKER_02:tall and one sort of hanging shelf So we don't get the bookcases like we have now but just one shelf that's attached to the wall And the people that we have to place uh you can see the list there along with their position and the project that they work on And I guess the question the first question is how we want to organise people Whether we want to do it by rank or by project or I don't know put all the P_H_D_ students together all the professors together that sort of thing So the idea is that we come up with a plan there's another group who's gonna be working on the same plan later this week And then Andre and I have to do presentations for the university administrators on the second So we have to come up with a plan possibly if we have time a presentation a quick presentation with arguments for why we think our plan works best Okay.\nSPEAKER_00:Mm-hmm.\nSPEAKER_03:Alright.\nSPEAKER_02:So anyone have any ideas or I guess.\nSPEAKER_00:Uh do we know if there will be a lot of people coming across the hall in terms of security stuff if we can I mean my idea is to put the photocopier and the fax in the hall.\nSPEAKER_02:Yeah.\nSPEAKER_00:Um Okay.\nSPEAKER_02:Um I think it's the security is sort of the same as it is in the current building.\nSPEAKER_02:So as long as the things are physically attached to the wall so.\nSPEAKER_00:Mm.\nSPEAKER_02:they can't be removed.\nSPEAKER_03:We can put it.\nSPEAKER_02:then it.\nSPEAKER_00:Okay Mm.\nSPEAKER_02:should be okay to leave them in the hall It's just a question of whether you are.\nSPEAKER_02:printing sensitive documents or.\nSPEAKER_03:Mm.\nSPEAKER_00:Mm yeah.\nSPEAKER_02:whatever.\nSPEAKER_04:So we only get one printer for fifteen people.\nSPEAKER_02:Um well we get one sort of networked printer and then I think some of us have personal printers I think Susan has a  ...

# %% [markdown]
# ##### Clean reference text

# %%
reference_transcript = []

for line in reference_text.splitlines():
    if line.strip():
        # Split the line into speaker and text
        speaker, text = line.split(":", 1)
        reference_transcript.append({
            "speaker": speaker.strip(),
            "text": text.strip()
        })

# %%
reference_transcript[:5]
# Out:
# [{'speaker': 'SPEAKER_02',
#   'text': "Okay So as you guys know ISSCO is too small Well the building is too small for our group So we're moving to a new building Uh it's gonna be the building across the street And we're actually moving in three weeks But the problem is that the administration wants to know who is going to be in what office in the new building and where we're we're gonna put things like the printer the fax machine all the big equipment And the catch is that they have the final approval of where we put people and equipment And they want to know where we're gonna do all this by November second So that means basically next Tuesday And since we don't really have any other time we have to make these decisions today What we're getting is nine rooms for a maximum of eighteen people which is okay 'cause there's only fifteen of us And all the rooms have windows luckily so there's no fights about who gets a window and who doesn't Um there's two views either of the old town or the mountains and the rooms have various sizes There's two three people rooms five two person rooms which are on the corners of the building so you actually get windows on two walls and two one person rooms That's pretty much what the building looks like Um and then you have the number of people per room The courtyard because we're on the sixth floor you can't actually go out to it but it just means that the windows look out onto open space Um you can see the bathrooms the elevators are sort of further down the hall The purple bar at the bottom sort of on the right is the mail-boxes All of the windows open you can get out onto the terrace just like we can in our normal building And the equipment that we have to put somewhere are like I said the photocopier which is really big the fax machine which is not so big and the printer which is relatively big Each office has a white board a bulletin board and a coat rack No cupboards like we have in the current offices and each person gets their own chair their own corner desk so like the the ones that we have now um a small filing cabinet with three drawers and by small I mean they're about that."},
#  {'speaker': 'SPEAKER_03', 'text': 'Mm-hmm.'},
#  {'speaker': 'SPEAKER_02',
#   'text': "tall and one sort of hanging shelf So we don't get the bookcases like we have now but just one shelf that's attached to the wall And the people that we have to place uh you can see the list there along with their position and the project that they work on And I guess the question the first question is how we want to organise people Whether we want to do it by rank or by project or I don't know put all the P_H_D_ students together all the professors together that sort of thing So the idea is that we come up with a plan there's another group who's gonna be working on the same plan later this week And then Andre and I have to do presentations for the university administrators on the second So we have to come up with a plan possibly if we have time a presentation a quick presentation with arguments for why we think our plan works best Okay."},
#  {'speaker': 'SPEAKER_00', 'text': 'Mm-hmm.'},
#  {'speaker': 'SPEAKER_03', 'text': 'Alright.'}]

# %% [markdown]
# ##### Prepare reference and hypothesis texts

# %%
reference_text_combined = " ".join([entry["text"] for entry in reference_transcript])
generated_text_combined = " ".join([entry["text"] for entry in generated_transcript if entry["text"].strip()])

# %%
reference_text_combined
# Out:
# "Okay So as you guys know ISSCO is too small Well the building is too small for our group So we're moving to a new building Uh it's gonna be the building across the street And we're actually moving in three weeks But the problem is that the administration wants to know who is going to be in what office in the new building and where we're we're gonna put things like the printer the fax machine all the big equipment And the catch is that they have the final approval of where we put people and equipment And they want to know where we're gonna do all this by November second So that means basically next Tuesday And since we don't really have any other time we have to make these decisions today What we're getting is nine rooms for a maximum of eighteen people which is okay 'cause there's only fifteen of us And all the rooms have windows luckily so there's no fights about who gets a window and who doesn't Um there's two views either of the old town or the mountains and the rooms have various sizes There's two three people rooms five two person rooms which are on the corners of the building so you actually get windows on two walls and two one person rooms That's pretty much what the building looks like Um and then you have the number of people per room The courtyard because we're on the sixth floor you can't actually go out to it but it just means that the windows look out onto open space Um you can see the bathrooms the elevators are sort of further down the hall The purple bar at the bottom sort of on the right is the mail-boxes All of the windows open you can get out onto the terrace just like we can in our normal building And the equipment that we have to put somewhere are like I said the photocopier which is really big the fax machine which is not so big and the printer which is relatively big Each office has a white board a bulletin board and a coat rack No cupboards like we have in the current offices and each person gets their own chair their own corner desk so like the the ones that we have now um a small filing cabinet with three drawers and by small I mean they're about that. Mm-hmm. tall and one sort of hanging shelf So we don't get the bookcases like we have now but just one shelf that's attached to the wall And the people that we have to place uh you can see the list there along with their position and the project that they work on And I guess the question the first question is how we want to organise people Whether we want to do it by rank or by project or I don't know put all the P_H_D_ students together all the professors together that sort of thing So the idea is that we come up with a plan there's another group who's gonna be working on the same plan later this week And then Andre and I have to do presentations for the university administrators on the second So we have to come up with a plan possibly if we have time a presentation a quick presentation with arguments for why we think our plan works best Okay. Mm-hmm. Alright. So anyone have any ideas or I guess. Uh do we know if there will be a lot of people coming across the hall in terms of security stuff if we can I mean my idea is to put the photocopier and the fax in the hall. Yeah. Um Okay. Um I think it's the security is sort of the same as it is in the current building. So as long as the things are physically attached to the wall so. Mm. they can't be removed. We can put it. then it. Okay Mm. should be okay to leave them in the hall It's just a question of whether you are. printing sensitive documents or. Mm. Mm yeah. whatever. So we only get one printer for fifteen people. Um well we get one sort of networked printer and then I think some of us have personal printers I think Susan has a personal. Yeah Yeah. printer Gisella has one maybe. I can't. and. remember. it Mm. who else Yeah But no-one else gets. their own printer In terms of equipment it's sort of the same thing as we have. Mm-hmm Mm. now Um So what I'd propose is that we sort of discuss various conc ...

# %%
generated_text_combined
# Out:
# " Okay, so as you guys know, ISCO is too small. Well, the building is too small for our group. So we're moving to a new building. It's going to be the building across the street and we're actually moving in three weeks. But the problem is that the administration wants to know who's going to be in what office in the new building and where we're going to put things like the printer, the fax machine, all the big equipment. And the catch is that they have the final approval of where we put people and equipment.  and they want to know where we're going to do all of this by November 2nd. So that means basically next Tuesday. And since we don't really have any other time, we have to make these decisions today. What we're getting is nine rooms for a maximum of 18 people, which is okay, because there's only 15 of us. And all the rooms have windows, luckily, so there's no fights about who gets a window and who doesn't. There's two views either of the old town or the mountains. And the rooms are various sizes. There's two three people rooms, five two person rooms, which are on the corners of the building. So you actually get windows on two walls.  today.  and two one-person rooms. That's pretty much what the building looks like and then you have the number of people per room. The courtyard, because we're on the sixth floor, you can't actually go out to it, but just means that the windows look out onto open space. You can see the bathrooms, the elevators are sort of further down the hall. The purple bar at the bottom, sort of on the right, is the mailboxes.  All of the windows open, you can get out onto the terrace just like we can in our normal building.  And the equipment that we have to put somewhere are, like I said, the photocopier, which is really big, the fax machine, which is not so big, and the printer, which is relatively big. Each office has a white board, a bulletin board, and a coat rack. No cupboards, like we have in the current offices. And each person gets their own chair, their own corner desk, so like the ones that we have now. A small filing cabinet with three drawers, and by small I mean they're about that tall. And one sort of hanging shelf. So we don't get the bookcases like we have now, but just one shelf that's attached to the wall.  And the people that we have to place, you can see the list there along with their position and the project that they work on. And I guess the question, the first question is how we want to organize people, whether we want to do it by rank or by project or...  I don't know, put all the PhD students together, all the professors together, and that sort of thing.  So the idea is that we come up with a plan. There's another group who's going to be working on the same plan later this week. And then Andre and I have to do presentations for the University administrators on the second. So I have to come up with a plan, possibly if we have time of presentation, a quick presentation with arguments for why we think our plan works best.  Okay. A rouge.  So anyone have any ideas or...  I guess.  Do we know if there will be a lot of people coming across the whole in terms of security stuff? I mean, my idea is to put the photocopy on the facts in the whole.  Yeah, I think the security is sort of the same as it is in the current building. So, as long as the things are physically attached to the wall so they can't be removed, then it should be okay to leave them in the hall.  So.  Okay.  It's just a question of whether you're printing the sensitive documents or whatever.  Whatever.  So we only get one printer for 15 people.  Well, we get one sort of networked printer. And then I think some of us have personal printers. Nothing Susan has a personal printer. Just Ella has one maybe. Yeah. I can't remember who else. Yeah, but no one else gets their own printer. In terms of equipment, it's sort of the same thing as we have now.  personal.  Yeah.  I can't remember.  So what I'd propose is that we sort of dis ...

# %% [markdown]
# #### Compute WER Score

# %%
wer_score = wer(reference_text_combined, generated_text_combined)

# %% [markdown]
# #### Compute BLEU Score

# %%
reference_tokens = [reference_text_combined.split()]
generated_tokens = generated_text_combined.split()
bleu_score = sentence_bleu(reference_tokens, generated_tokens)

# %%
print(f"Word Error Rate (WER): {wer_score * 100:.4f}")
print(f"BLEU Score: {bleu_score * 100:.4f}")
# Out:
# Word Error Rate (WER): 57.1203
# BLEU Score: 38.6883

# %% [markdown]
# BLEU Score - Higher the better
#
# Word Error Rate - Lower the better
#
#
# I think the inaccuracy is due to the punctuations and the spellings of different words along with the fact that the model picks up even the talking at the back which is not required.
